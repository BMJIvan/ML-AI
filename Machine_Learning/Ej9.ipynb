# %%
#distribucion uniforme numeros equiprobables
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
a=1
b=100
n=2000
data=np.random.uniform(a,b,n)

# %%
# %matplotlib inline

# %%
plt.hist(data)
# Out:
# (array([198., 211., 186., 192., 210., 172., 191., 203., 235., 202.]),
#  array([ 1.00713577, 10.90367515, 20.80021453, 30.69675391, 40.59329329,
#         50.48983267, 60.38637205, 70.28291143, 80.17945081, 90.07599019,
#         99.97252957]),
#  <BarContainer object of 10 artists>)

# %%
#distribucion normal
data=np.random.randn(10000)

# %%
x=range(1,10001)
plt.plot(data)

# %%
plt.hist(data)
# Out:
# (array([   9.,  104.,  474., 1472., 2568., 2761., 1769.,  674.,  140.,
#           29.]),
#  array([-3.7497639 , -3.01729364, -2.28482338, -1.55235313, -0.81988287,
#         -0.08741261,  0.64505765,  1.37752791,  2.10999816,  2.84246842,
#          3.57493868]),
#  <BarContainer object of 10 artists>)

# %%
plt.plot(x,sorted(data))

# %%
mu=5.5
sd=2.5
data2=mu+sd*np.random.randn(10000)#z=(x-mu)/sd -> N(0,1),x=mu +sd*z//teorema central del limite
plt.hist(data2)
# Out:
# (array([2.000e+00, 3.700e+01, 2.390e+02, 1.222e+03, 2.590e+03, 3.138e+03,
#         1.980e+03, 6.680e+02, 1.130e+02, 1.100e+01]),
#  array([-5.30737974, -3.25987275, -1.21236575,  0.83514124,  2.88264824,
#          4.93015523,  6.97766223,  9.02516922, 11.07267622, 13.12018321,
#         15.16769021]),
#  <BarContainer object of 10 artists>)
